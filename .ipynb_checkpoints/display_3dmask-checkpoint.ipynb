# %%
import JupyterNotebooksLib as slicernb
import ScreenCapture
import os
slicernb.showSliceViewAnnotations(False)

# %% [markdown]
# ## lung mask

# %%
path = r"Y:\paper_COPD\xinzeng\airway\COPD"
save_path = r"C:\Users\User\Desktop\temp\COPD"
# k = 0
# save_list = os.listdir(save_path)
for f in os.listdir(path):
    # Clear scene
    slicer.mrmlScene.Clear(False)
    img_path = os.path.join(path, f)
    volume = slicer.util.loadVolume(img_path)
    slicernb.showVolumeRendering(volume, presetName='Vesselness')
    slicernb.reset3DView(viewID=0)
    threeDWidget = slicer.app.layoutManager().threeDWidget(0)
    threeDView = threeDWidget.threeDView()
    threeDView.resetCamera()
    threeDView.resize(512,512)
    
    viewNode = slicer.app.layoutManager().threeDWidget(0).mrmlViewNode()
    viewNode.SetBackgroundColor(1,1,1)
    viewNode.SetBackgroundColor2(1,1,1)
    
    name = f[:9]
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, 0, 0])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_1.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, save_list[k], f + '_1.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, f + '_1.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_1.png'))
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, 0, 180])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_2.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, save_list[k], f + '_2.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, f + '_2.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_2.png'))
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, -90, 0])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_3.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, save_list[k], f + '_3.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, f + '_3.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_3.png'))
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, 90, 0])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_4.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, save_list[k], f + '_4.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, f + '_4.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_4.png'))
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, 0, 90])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_5.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, save_list[k], f + '_5.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, f + '_5.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_5.png'))
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, 0, -90])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_6.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, save_list[k], f + '_6.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, f + '_6.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_6.png'))
    
#     k += 1

# %% [markdown]
# ## airway mask

# %%
path = r"Y:\paper_COPD\xinzeng\airway\COPD"
save_path = r"Y:\paper_COPD\snapshot\airway\COPD"
k = 0
save_list = os.listdir(save_path)
for f in os.listdir(path):
    
    name = f[:9]
    
    # Clear scene
    slicer.mrmlScene.Clear(False)
    img_path = os.path.join(path, f)
    volume = slicer.util.loadVolume(img_path)
    slicernb.showVolumeRendering(volume, presetName='Vesselness')
    slicernb.reset3DView(viewID=0)
    threeDWidget = slicer.app.layoutManager().threeDWidget(0)
    threeDView = threeDWidget.threeDView()
    threeDView.resetCamera()
    threeDView.resize(512,512)
    
    viewNode = slicer.app.layoutManager().threeDWidget(0).mrmlViewNode()
    viewNode.SetBackgroundColor(1,1,1)
    viewNode.SetBackgroundColor2(1,1,1)
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, 0, 0])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_1.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), name + '_1.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_1.png'))
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, 0, 180])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_2.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), name + '_2.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_2.png'))
    
    # 保存图像
    slicernb.View3DDisplay(0, orientation=[0, -45, 0])
    viewNodeID = "vtkMRMLViewNode1"
    cap = ScreenCapture.ScreenCaptureLogic()
    view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), f + '_3.png'))
#     cap.captureImageFromView(view, os.path.join(save_path, str(k), name + '_3.png'))
    cap.captureImageFromView(view, os.path.join(save_path, name + '_3.png'))
    
    k += 1

# %% [markdown]
# # Enable volume cropping
# displayNode = slicer.modules.volumerendering.logic().GetFirstVolumeRenderingDisplayNode(volume)
#
# displayNode.SetCroppingEnabled(True)
#
# roiNode = displayNode.GetROINode()
#
# # 3D view display
# slicernb.reset3DView()
#
# from ipywidgets import interact
#
# @interact(roll=(-180.0,180.0,5), pitch=(-180.0,180.0,5), yaw=(-180.0,180.0,5), cropx=(0,512,1), cropy=(0,512,5), cropz=(0, 512, 1))
#
# def update(roll=0, pitch=0, yaw=0, cropx=80, cropy=80, cropz=80):
#
#     roiNode.SetRadiusXYZ([cropx, cropy, cropz])
#
#     return slicernb.View3DDisplay(0, orientation=[roll, pitch, yaw])

# %%
# Clear scene
slicer.mrmlScene.Clear(False)
testPath = r"Y:\paper_COPD\xinzeng\airway\COPD\duran_020_0000_airway_large.nii.gz"
# testPath = r"F:\my_code\slicer\data\img\lobe512_000_0000.nii.gz"
volume = slicer.util.loadVolume(testPath)
slicernb.showVolumeRendering(volume, presetName='Vesselness')
# slicernb.showVolumeRendering(volume)
slicernb.reset3DView(viewID=0)
threeDWidget = slicer.app.layoutManager().threeDWidget(0)


viewNode = slicer.app.layoutManager().threeDWidget(0).mrmlViewNode()
viewNode.SetBackgroundColor(1,1,1)
viewNode.SetBackgroundColor2(1,1,1)

threeDView = threeDWidget.threeDView()
threeDView.resetCamera()
slicernb.View3DDisplay(0, orientation=[0, -45, 0])
threeDView.resize(512,512)

# 保存图像
viewNodeID = "vtkMRMLViewNode1"
cap = ScreenCapture.ScreenCaptureLogic()
view = cap.viewFromNode(slicer.mrmlScene.GetNodeByID(viewNodeID))
cap.captureImageFromView(view, 'test1.png')
